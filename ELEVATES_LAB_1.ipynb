# %% [markdown]
# # TASK_1 ; DATA CLEANING AND PREPROCESSING

# %% [markdown]
# ## MALL CUSTOMER SEGMENTAION DATA SETS

# %%
## IMPORT LIBRARIES 
import pandas as pd

# %%
## import data 

mall_data  = pd.read_csv("Mall_Customers.csv")

# %%
## show first 5 rows data

mall_data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
## checking how many rows and columns in data 
mall_data.shape
# Out:
# (200, 5)

# %% [markdown]
# #### "The Mall Customer Segmentation dataset contains 200 rows and 5 columns."

# %%
## checking nulls in data 
mall_data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# #### “This dataset has no null values.”

# %%
### checking duplicates 
mall_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### "There are no duplicates in this datasets"

# %%
### checking data format using .info()
mall_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
## separately show only integer and categorial  type columns
int_column = mall_data.select_dtypes(include = "int")

# %%
# integers column
int_column.head()
# Out:
#    CustomerID  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   19                  15                      39
# 1           2   21                  15                      81
# 2           3   20                  16                       6
# 3           4   23                  16                      77
# 4           5   31                  17                      40

# %%
# categorial columns
cat_column = mall_data.select_dtypes(include = "object")
cat_column.head()
# Out:
#    Gender
# 0    Male
# 1    Male
# 2  Female
# 3  Female
# 4  Female

# %% [markdown]
# ## Then Save Cleaned Data
